# %%
# %matplotlib inline
import matplotlib as mlp
import scipy
import numpy as np
import sympy
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.collections import PatchCollection
from sklearn.preprocessing import scale
from scipy.stats.stats import pearsonr 
from sklearn.linear_model import LinearRegression
from sklearn import cross_validation
from sklearn import metrics

# %% [markdown]
# # Population Data Map
# The below Data map shows the population of countries. The interesting thing to notice here is the fact that most of the entire population is located in a circle containing China, India, Bangladesh, Indonesia, Pakistan etc.

# %%
col_name = []
country_data = pd.read_csv("./country-data.csv", na_values='unknown')

for name in country_data:
    print name

for name in country_data:
    col_name.append(name)

col_name = col_name[7:]

country_data = country_data.replace("1.78%",1.78)

for i in col_name:
    country_data[i] = (country_data[i].fillna(country_data[i].astype(float).mean())).astype(float)
####################
#create Datamap
####################
map = Basemap(width=24000000,height=18000000,projection='cyl',
        resolution='c',lat_1=45,lat_2=54,lat_0=50,lon_0=0)
# draw coastlines.
map.drawcoastlines()
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral',lake_color='cyan')
map.drawcountries()

# load the shapefile, use the name 'name'


map.readshapefile('ne_110m_admin_0_countries', name='country', drawbounds=True)

# collect the  names from the shapefile attributes so we can
# look up the shape obect for a country by it's name

country_names = []
colors = []
patches = []
colormap = plt.get_cmap('Reds')
for shape_dict in map.country_info:
    country_names.append(shape_dict['name'])


for i in range (0, len(country_data)):
    color = colormap(country_data.at[i,'Population']/float(country_data['Population'].max()))
    colors.append(color)
    ax = plt.gca() # get current axes instance

    try:
        find_name = country_data.at[i,'Country Name']
        indices = [j for j, x in enumerate(country_names) if x == find_name]
        for k in indices:
            seg = map.country[k]
            poly = Polygon(seg, facecolor=color,edgecolor=color)
            patches.append(poly)
            ax.add_patch(poly)
    except ValueError:
        pass


p = PatchCollection(patches, cmap=colormap)
p.set_array(np.array(country_data['Population']))
cb = plt.colorbar(p)

plt.show()
# Out:
# Country Name
# Country Code
# Government Type
# Capital City
# Date of Founding/Independence
# Latitude of Capital
# Longitude of Capital
# Population
# Life Expectancy
# GDP (PPP) in US $
# Area (sq km)
# Land Boundaries (km)
# Coastline (km)
# Literacy Rate (%)
# Health Expenditure/GDP
# Military Expenditure/GDP
# Renewable Water Resources (cu km)
# Net Migration Rate/1000 Population
# Labor Force
# Internet Users (circa 2009)
# Commercial Prime Lending Rate
# warning: width and height keywords ignored for Cylindrical Equidistant projection

# %% [markdown]
# # Scatter plot - Health exp/GDP vs GDP/Capita
# The below plot reveals that there might be a correlation between the 2 entities. Countries with higher GDP definitely spend more on Health

# %%
####################
#create Scatter plots
####################
## Health exp/GDP  vs  GDP/Capita
#insert some new data based on pop

gdp_pc = np.float32(country_data['GDP (PPP) in US $']) /  np.float32(country_data['Population'])
country_data.insert(1,'GDP per capita', gdp_pc )


normed_pop = np.array((country_data['Population'] - country_data['Population'].mean()) /
                                        country_data['Population'].std(ddof=0))
#create scatter plot for each country
x = np.float32(country_data['GDP per capita'])
y = np.float32(country_data['Health Expenditure/GDP'])

colors = np.random.rand(len(country_data))
area = np.pi * (np.log10(normed_pop*100)*2)**3  # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)

plt.xlabel("GDP per capita")
plt.ylabel("Health Expenditure / GDP")
plt.show()

# %% [markdown]
# # Scatter plot - Literacy Rate vs Labor Force
# In the below plot, it can be seen that the countries are distributed towards the X-axis. This might be because Labor force measures do not reveal the income of the work force in question. Countries with bigger population (shown by the size of the dots) tend to have the biggest work forces. It can be seen that the 2 countries with the biggest populations, India and China, have obviously the biggest Labor force.

# %%
####################
#create Scatter plots
####################
## Literacy  vs  Labor Force

normed_lit = np.array((country_data['Literacy Rate (%)'] - country_data['Literacy Rate (%)'].mean()) /
                  country_data['Literacy Rate (%)'].std(ddof=0))

normed_lab = np.array((country_data['Labor Force'] - country_data['Labor Force'].mean()) /
                  country_data['Labor Force'].std(ddof=0))
#create scatter plot for each country
x = normed_lit
y = normed_lab

colors = np.random.rand(len(country_data))
area = np.pi * (np.log10(normed_pop*100)*2)**3  # 0 to 15 point radiuses

plt.scatter(x, y, s=area, c=colors, alpha=0.5)

plt.xlabel("Literacy Rate (normalised)")
plt.ylabel("Labor Force (normalised)")
plt.show()

# %% [markdown]
# # Histogram - Military exp/GDP
#
# The below histogram reveals that most countries spend equivalently on military. Looks like very few countries spend more than their financial capabilities.

# %%
####################
#create Histograms
####################
## Military Expenditure/GDP

normed_mil = np.array((country_data['Military Expenditure/GDP'] - country_data['Military Expenditure/GDP'].mean()) /
                      country_data['Military Expenditure/GDP'].std(ddof=0))

fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.hist(normed_mil, 50, normed=1, facecolor='green', alpha=0.75)
ax1.set_xlabel('Military Expenditure/GDP')
ax1.set_ylabel('Number of countries')
ax1.axvline(normed_mil.mean(), color='b', linestyle='dashed', linewidth=2)
ax1.grid(True)

# %% [markdown]
# # Histogram - Internet Users
#
# The below histogram reveals that most countries are on the lower end of internet users spectrum. The mean is low. However, a graph showing internet users/ total pop would reveal more interesting results.

# %%
## Internet Users

normed_internet = np.array((country_data['Internet Users (circa 2009)'] - country_data['Internet Users (circa 2009)'].mean()) /
                      country_data['Internet Users (circa 2009)'].std(ddof=0))

fig2 = plt.figure()
ax2 = fig2.add_subplot(111)
ax2.hist(normed_internet, 50, normed=1, facecolor='blue', alpha=0.75)
ax2.set_xlabel('Internet Users')
ax2.set_ylabel('Number of countries')
ax2.axvline(normed_internet.mean(), color='r', linestyle='dashed', linewidth=2)
ax2.grid(True)

# %% [markdown]
# # Question 2 - Pearson Coefficient and Permutation test

# %%
######## Q2 ############
max_p_val = 0
min_p_val=0

max_k_val = 0
min_k_val=0

corr_matrix = np.zeros(shape=(len(col_name),len(col_name)))
for i in range(0,len(col_name)):
    for j in range(0,len(col_name)):
        if (i != j):
            [k,p]=pearsonr(country_data[col_name[i]].astype(float), country_data[col_name[j]].astype(float))
            corr_matrix[i][j] = float(k)
            if(max_k_val < k):
                max_k_val = k
                max_p_val = p
            if(min_k_val > k):
                min_k_val = k
                min_p_val = p

i_max,j_max = np.unravel_index(corr_matrix.argmax(), corr_matrix.shape)
i_min,j_min = np.unravel_index(corr_matrix.argmin(), corr_matrix.shape)

print "Most correlated metrics are " + col_name[i_max] + " and " + col_name[j_max] + " with factor", corr_matrix[i_max][j_max]


### Permutation test
permute = []
count_max_p_val=0
count_min_p_val=0
permutation_test = 10000


for i in range(0, permutation_test):
    [k,p]=pearsonr(country_data[col_name[i_max]].astype(float),
                   np.random.permutation(country_data[col_name[j_max]].astype(float)))
    permute.append(k)
    #now check the number of tests for which the correlation is higher than the actual value
    if( k > corr_matrix[i_max][j_max]):
        count_max_p_val +=1


print "max value in permutation test =", max_k_val
print "max p_value in permutation test =", max_p_val
print "Fractions producing correlation higher =",(count_max_p_val/permutation_test)

permute = []
for i in range(0, permutation_test):
    [k,p]=pearsonr(country_data[col_name[i_min]].astype(float),
                   np.random.permutation(country_data[col_name[j_min]].astype(float)))
    permute.append(k)
    #now check the number of tests for which the correlation is higher than the actual value
    if( k < corr_matrix[i_min][j_min]):
        count_min_p_val +=1


        
print "\n\nLeast correlated metrics are " + col_name[i_min] + " and " + col_name[j_min] + " with factor", corr_matrix[i_min][j_min]
print "min value in permutation test =", min_k_val
print "min p_value in permutation test =", min_p_val

print "Fractions producing correlation Lower =",(count_min_p_val/permutation_test)
# Out:
# Most correlated metrics are Population and Labor Force with factor 0.980172630031
# max value in permutation test = 0.980172630031
# max p_value in permutation test = 4.75192220857e-139
# Fractions producing correlation higher = 0
#
#
# Least correlated metrics are Life Expectancy and Commercial Prime Lending Rate with factor -0.441828547965
# min value in permutation test = -0.441828547965
# min p_value in permutation test = 8.06070133067e-11
# Fractions producing correlation Lower = 0

# %% [markdown]
# # Question 3 - Linear Regression
#
# In the below test result, GDP per capita is showing least error with Life expectancy.

# %%
############## Q3 ############

normed_gdp_pc = np.array((country_data['GDP per capita'] - country_data['GDP per capita'].mean()) /
                  country_data['GDP per capita'].std(ddof=0))

country_data = country_data.replace("1.78%",1.78)

for i in col_name:
    country_data[i] = (country_data[i].fillna(country_data[i].astype(float).mean())).astype(float)

for name in col_name:

    normed_value = np.array((country_data[name] - country_data[name].mean()) /
                  country_data[name].std(ddof=0))


    X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(normed_value.reshape(-1,1),
                                            normed_gdp_pc.reshape(-1,1), test_size = 0.8, random_state = 0)
    linReg = LinearRegression()
    linReg.fit(X_train, Y_train)
    error = metrics.mean_squared_error(Y_test, linReg.predict(X_test))
    print name ," vs GDP per capita Error -> ",error
    plt.scatter(X_train, Y_train)

    plt.plot(X_test, linReg.predict(X_test))
    plt.show()
# Out:
# Population  vs GDP per capita Error ->  1.38105859948
# Life Expectancy  vs GDP per capita Error ->  0.798271294795
# GDP (PPP) in US $  vs GDP per capita Error ->  1.15931587033
# Area (sq km)  vs GDP per capita Error ->  1.25648418878
# Land Boundaries (km)  vs GDP per capita Error ->  1.29014131103
# Coastline (km)  vs GDP per capita Error ->  1.13715270497
# Literacy Rate (%)  vs GDP per capita Error ->  0.966438811411
# Health Expenditure/GDP  vs GDP per capita Error ->  1.23564889154
# Military Expenditure/GDP  vs GDP per capita Error ->  1.26180894065
# Renewable Water Resources (cu km)  vs GDP per capita Error ->  1.22286636492
# Net Migration Rate/1000 Population  vs GDP per capita Error ->  1.48288231626
# Labor Force  vs GDP per capita Error ->  1.38761060008
# Internet Users (circa 2009)  vs GDP per capita Error ->  1.21979628174
# Commercial Prime Lending Rate  vs GDP per capita Error ->  1.18031070677

# %% [markdown]
# #  Question 4 - Calculating Social Welfare
#
# Some Economists, like Amartya Sen, have proposed ways to measure social welfare of an economic state. However, most of the measure, apart from GDP being of the highest importance, take wealth inequality as a huge measure in order to calculate social welfare. In lieu of this information not being available, Social welfare of a country has been calculated based upon GDP per Capita, and other HDI indicators. Some would argue that Literacy rate and miltary strength should be taken into account because security and education should count in social welfare.
#
# Monaco made to the top of the list. Many deserving nations are present in the top 10 including Norway and Switzerland.
# Points noticed are as follows ->
#
#     1. When only considering GDP per capita, countries like Brunei made to the top of the list. This is because Brunei is a very rich nation due to a lot of Oil and their population is relatively low. However their wealth distribution is not very good and they have a relatively low HDI. Same goes for some gulf countries as well.
#     2. Bottom of the list is dominated by developing nations as is expected. But there are skewed results like Zimbabwe which is nearly a failed state is above many relatively doing well nations like Pakistan, Nigeria and Myanmar(Burma).
#
# Overall, this measure lacks a lot of accuracy mostly because a good data regarding wealth distribution wasn't present.

# %%
############## Q4 ############

country_names = country_data[['Country Name']]

#Normalise the required data -> gdp/pop, internet_users/pop,

normed_life = np.array(list((country_data['Life Expectancy'] - country_data['Life Expectancy'].mean()) /
                  country_data['Life Expectancy'].std(ddof=0)))

normed_gdp = np.array(list((country_data['GDP per capita'] - country_data['GDP per capita'].mean()) /
                  country_data['GDP per capita'].std(ddof=0)))
normed_health = np.array(list((country_data['Health Expenditure/GDP'] - country_data['Health Expenditure/GDP'].mean()) /
                  country_data['Health Expenditure/GDP'].std(ddof=0)))

#Fill in the nan values with definite values
normed_health = np.nan_to_num(normed_health)

### Scoring function

normed_data = normed_life * 0.3 + normed_gdp * 0.7 + normed_health*0.4

country_names.insert(1,'Social Welfare Index', normed_data)

result = country_names.sort_values(by=['Social Welfare Index'], ascending=[0])
result
# Out:
#                  Country Name  Social Welfare Index
# 116                    Monaco              6.416227
# 187             United States              2.957332
# 100             Liechtenstein              2.649434
# 102                Luxembourg              2.564085
# 141                     Qatar              2.108095
# 130                    Norway              1.917304
# 169               Switzerland              1.899192
# 125               Netherlands              1.854401
# 31                     Canada              1.834477
# 9                     Austria              1.713598
# 63                    Germany              1.657090
# 156                 Singapore              1.602980
# 16                    Belgium              1.589009
# 59                     France              1.585694
# 8                   Australia              1.576655
# 46                    Denmark              1.562824
# 168                    Sweden              1.498191
# 84                      Japan              1.463415
# 75                    Iceland              1.461759
# 80                    Ireland              1.417286
# 186            United Kingdom              1.335154
# 126               New Zealand              1.245536
# 58                    Finland              1.245382
# 149                San Marino              1.224886
# 82                      Italy              1.148198
# 163                     Spain              1.137322
# 3                     Andorra              1.112788
# 92                     Kuwait              1.105084
# 171                    Taiwan              1.076438
# 81                     Israel              1.065740
# ..                        ...                   ...
# 167                 Swaziland             -0.930116
# 111                Mauritania             -0.953176
# 37                    Comoros             -0.963740
# 69                     Guinea             -1.003152
# 196                  Zimbabwe             -1.019776
# 162               South Sudan             -1.030974
# 61                Gambia, The             -1.031814
# 108                      Mali             -1.050201
# 87                      Kenya             -1.051061
# 104                Madagascar             -1.075453
# 60                      Gabon             -1.081854
# 26               Burkina Faso             -1.086732
# 18                      Benin             -1.124623
# 122                   Namibia             -1.129456
# 56                   Ethiopia             -1.135537
# 30                   Cameroon             -1.147455
# 120                Mozambique             -1.156666
# 160                   Somalia             -1.157278
# 132                  Pakistan             -1.164132
# 195                    Zambia             -1.230405
# 94                       Laos             -1.238795
# 128                     Niger             -1.271027
# 129                   Nigeria             -1.280193
# 70              Guinea-Bissau             -1.287708
# 4                      Angola             -1.295231
# 121                     Burma             -1.299586
# 54                    Eritrea             -1.341644
# 39     Congo, Republic of the             -1.405138
# 33                       Chad             -1.530380
# 32   Central African Republic             -1.593145
#
# [197 rows x 2 columns]

# %% [markdown]
# #  Question 5 - Calculating Neighboring States
#
# The definition of a country being "similar" to another is very vague. One usually thinks of cultural similarity when bombarded with this question. If you ask for Japan, one would usually reply with China, South Korea, Taiwan. Similarly for Denmark, it will be Sweden, Norway and Finland.
#
# However, to find out what other countries might be similar to one, we can take other factors like Life expectancy, GDP per capita, internet users and other such metrics into consideration. A statistical distance can be calculated and then the countries can be clustered based upon this distance.
#
# Total of 10 neighboring countries have been printed along with closest and farthest neighbors
#
# Observations ->
# 1. Strange pairs like (India Syria), (Canada	Switzerland), (Brazil	Montenegro), (Greenland	Bahamas, The) (China	Tonga) and many others have been observed.
# 2. Interesting pairs like (Brunei	United Arab Emirates) -> Both are Oil based extremely rich small countries.
#                      (Singapore	Kuwait) -> Both are Trading focal points and major seaports.
#                      (Iceland	Sweden) -> Nordic countries
#
# 3. Goof up in farthest neighbor being nearly same for all.
#
# Even though the most neighboring countries might be a little skewed, the top 10 set shows better results.

# %%
############## Q5 ############

internet_users_pc = np.float32(country_data['Internet Users (circa 2009)']) /  np.float32(country_data['Population'])
country_data.insert(1,'Internet users per capita', internet_users_pc )

internet_users = country_data[['Country Name','Internet Users (circa 2009)']]

# Normalise the required data -> gdp/pop, internet_users/pop,


normed_internet = np.array(list((country_data['Internet users per capita'] - country_data['Internet users per capita'].mean()) /
                  country_data['Internet users per capita'].std(ddof=0)))

normed_life = np.array(list((country_data['Life Expectancy'] - country_data['Life Expectancy'].mean()) /
                  country_data['Life Expectancy'].std(ddof=0)))

normed_gdp = np.array(list((country_data['GDP per capita'] - country_data['GDP per capita'].mean()) /
                  country_data['GDP per capita'].std(ddof=0)))
normed_health = np.array(list((country_data['Health Expenditure/GDP'] - country_data['Health Expenditure/GDP'].mean()) /
                  country_data['Health Expenditure/GDP'].std(ddof=0)))

arr = np.array([normed_gdp, normed_internet, normed_life, normed_health])

distance_matrix = np.zeros(shape=(197,197))

dataframe_final = pd.DataFrame(columns=('Country','Closest','Farthest'))

for i in range (0, len(country_data)):

    #calculate distance for ith country wrt every other country

    for j in range (0, len(country_data)):

        # calculate distance between the 2 countries and keep in array
        if ( i==j):
            distance_matrix[i][j] = 0
        else:
            distance_matrix[i][j] = scipy.spatial.distance.euclidean(arr[:,i],arr[:,j])

    #sort the list

    print country_data.iat[i,0] + " = "
    temp_array = distance_matrix[i].argsort()

    dataframe_final.loc[i] = [country_data.iat[i,0], country_data.iat[temp_array[1],0], country_data.iat[temp_array[len(country_data)-1],0]]
    print (" ".join(country_data.iat[k,0] for k in distance_matrix[i].argsort()[1:12]))
print dataframe_final
dataframe_final.to_csv("./final.csv")
# Out:
# Afghanistan =
# Uganda Swaziland South Africa Congo, Democratic Republic of the Somalia South Sudan Mozambique Zimbabwe Burundi Rwanda Mali
# Albania =
# Lebanon Tunisia Morocco Macedonia Dominica Dominican Republic Colombia Saint Lucia Ecuador Mexico Tonga
# Algeria =
# Sri Lanka Libya Thailand Armenia Vanuatu Saint Vincent and the Grenadines Philippines Egypt China Tonga Fiji
# Andorra =
# San Marino Israel Taiwan Korea, South Finland Czech Republic Iceland Malta Australia Japan United Kingdom
# Angola =
# Congo, Republic of the Central African Republic Gabon Cameroon Niger Botswana Nigeria Namibia Chad Ethiopia Benin
# Antigua and Barbuda =
# Mauritius Dominica Mexico Romania Colombia Poland Grenada Venezuela Lebanon Estonia Lithuania
# Argentina =
# Uruguay Panama Croatia Chile Cyprus Hungary Saint Lucia Lithuania Bulgaria Barbados Slovakia
# Armenia =
# Thailand Vanuatu Egypt Philippines Algeria Fiji Peru Libya Jamaica Cabo Verde China
# Australia =
# Iceland Sweden Ireland United Kingdom Finland Japan Norway Austria Belgium Israel Switzerland
# Austria =
# Belgium Germany Canada Switzerland Denmark Ireland Sweden Netherlands United Kingdom Iceland Australia
# Azerbaijan =
# Suriname Jamaica Peru Belarus Egypt Iran Venezuela Cabo Verde Uzbekistan Saint Vincent and the Grenadines China
# Bahamas, The =
# Greenland Barbados Estonia Czech Republic Hungary Slovenia Slovakia Latvia Korea, South Poland Lithuania
# Bahrain =
# Seychelles Saudi Arabia Saint Kitts and Nevis Malaysia Oman Libya Saint Vincent and the Grenadines Antigua and Barbuda Venezuela Estonia Thailand
# Bangladesh =
# Fiji Philippines Vanuatu Syria Bhutan India Cabo Verde Indonesia Papua New Guinea Armenia Bolivia
# Barbados =
# Hungary Croatia Lithuania Czech Republic Poland Uruguay Argentina Bulgaria Chile Cyprus Slovakia
# Belarus =
# Suriname Azerbaijan Venezuela Peru Iran Trinidad and Tobago Saint Vincent and the Grenadines Jamaica Romania Grenada Russia
# Belgium =
# Austria Germany Denmark Canada Switzerland Ireland Sweden United Kingdom France New Zealand Netherlands
# Belize =
# Guyana Mongolia Bolivia Iran Tajikistan Kyrgyzstan Nepal Suriname Azerbaijan Russia Kosovo
# Benin =
# Ethiopia Kenya Mauritania Comoros Gambia, The Cameroon Senegal Cambodia Madagascar Guinea Yemen
# Bhutan =
# Syria India Bolivia Papua New Guinea Bangladesh Kazakhstan Fiji Cabo Verde Mongolia Philippines Vanuatu
# Bolivia =
# Mongolia Bhutan Nepal Papua New Guinea Belize Ghana Cabo Verde India Tajikistan Guyana Syria
# Bosnia and Herzegovina =
# Paraguay Serbia Cuba Georgia Costa Rica Montenegro Nicaragua Solomon Islands Brazil Maldives Jordan
# Botswana =
# Namibia Nigeria Gabon Angola Niger Cameroon Zambia Burkina Faso Chad Mozambique Central African Republic
# Brazil =
# Montenegro Maldives Iraq Jordan Georgia Honduras Solomon Islands Bulgaria Nicaragua Paraguay Serbia
# Brunei =
# United Arab Emirates Kuwait Saudi Arabia Oman Singapore Bahrain Seychelles Taiwan Malaysia Saint Kitts and Nevis Estonia
# Bulgaria =
# Hungary Croatia Uruguay Turkey Lithuania Ecuador Latvia Saint Lucia Argentina Mexico Macedonia
# Burkina Faso =
# Mali South Sudan Zimbabwe Mozambique Zambia Cote d'Ivoire Somalia Niger Nigeria Cameroon Guinea-Bissau
# Burundi =
# Malawi Congo, Democratic Republic of the Djibouti Sudan Haiti Tanzania Togo Sao Tome and Principe Uganda Cote d'Ivoire Western Sahara
# Cabo Verde =
# Egypt Philippines Vanuatu Uzbekistan Jamaica Azerbaijan Mongolia Fiji Bolivia Armenia Peru
# Cambodia =
# Yemen Comoros Mauritania Senegal Tajikistan Ghana Nepal Kenya Gambia, The Benin Ethiopia
# Cameroon =
# Niger Guinea Ethiopia Benin Senegal Burkina Faso Nigeria Cote d'Ivoire Mauritania Mali Zimbabwe
# Canada =
# Switzerland Germany Austria Netherlands Belgium Denmark France Sweden Ireland New Zealand United Kingdom
# Central African Republic =
# Chad Nigeria Angola Namibia Niger Zambia Cameroon Gabon Guinea-Bissau Botswana Congo, Republic of the
# Chad =
# Central African Republic Nigeria Namibia Zambia Guinea-Bissau Niger Angola Botswana Mozambique Gabon Cameroon
# Chile =
# Cyprus Argentina Panama Croatia Uruguay Saint Lucia Lithuania Hungary Poland Czech Republic Barbados
# China =
# Tonga Saint Vincent and the Grenadines Jamaica Venezuela Peru Egypt Romania Libya Dominican Republic Colombia Dominica
# Colombia =
# Tunisia Romania Macedonia Grenada Dominica Mexico Mauritius Lebanon China Morocco El Salvador
# Comoros =
# Mauritania Cambodia Yemen Kenya Gambia, The Ghana Benin Ethiopia Senegal Nepal Tajikistan
# Congo, Democratic Republic of the =
# Burundi Malawi Uganda Zimbabwe South Sudan Cote d'Ivoire Mali Tanzania Djibouti Burkina Faso Swaziland
# Congo, Republic of the =
# Angola Laos Eritrea Benin Ethiopia Burma Kenya Gambia, The Cameroon Central African Republic Madagascar
# Costa Rica =
# Cuba Bosnia and Herzegovina Serbia Portugal Paraguay Georgia Montenegro Nicaragua Slovakia Brazil Greece
# Cote d'Ivoire =
# Zimbabwe Guinea Mali Burkina Faso South Sudan Tanzania Senegal Western Sahara Cameroon Malawi Congo, Democratic Republic of the
# Croatia =
# Uruguay Hungary Argentina Panama Cyprus Chile Bulgaria Lithuania Saint Lucia Barbados Ecuador
# Cuba =
# Bosnia and Herzegovina Paraguay Costa Rica Serbia Georgia Montenegro Portugal Maldives Solomon Islands Brazil Panama
# Cyprus =
# Chile Argentina Croatia Saint Lucia Uruguay Panama Lithuania Poland Hungary Czech Republic Ecuador
# Czech Republic =
# Chile Korea, South Cyprus Poland Barbados Malta Lithuania Hungary Argentina Croatia Israel
# Denmark =
# Germany Belgium France Austria Netherlands Canada New Zealand Switzerland Ireland United Kingdom Sweden
# Djibouti =
# Haiti Sudan Togo Sao Tome and Principe Tanzania Malawi Western Sahara Burundi Cote d'Ivoire Senegal Congo, Democratic Republic of the
# Dominica =
# Mauritius Antigua and Barbuda Colombia Lebanon Romania Mexico Tunisia Dominican Republic Macedonia Albania Grenada
# Dominican Republic =
# Tonga Dominica Albania China Lebanon Morocco Tunisia Colombia Saint Vincent and the Grenadines Libya Romania
# Ecuador =
# Saint Lucia Macedonia El Salvador Bulgaria Lebanon Tunisia Albania Croatia Uruguay Mexico Samoa
# Egypt =
# Jamaica Uzbekistan Armenia Cabo Verde Peru China Azerbaijan Vanuatu Philippines Tonga Thailand
# El Salvador =
# Samoa Vietnam Macedonia Tunisia Guatemala Colombia Ecuador Turkey Grenada Morocco Romania
# Equatorial Guinea =
# Timor-Leste Kazakhstan Turkmenistan Bhutan Russia Syria Trinidad and Tobago Belize Ghana Guyana India
# Eritrea =
# Laos Burma Pakistan Madagascar Congo, Republic of the Gambia, The Kenya India Papua New Guinea Syria Benin
# Estonia =
# Trinidad and Tobago Latvia Antigua and Barbuda Poland Mauritius Mexico Lithuania Belarus Romania Grenada Turkey
# Ethiopia =
# Benin Mauritania Kenya Comoros Gambia, The Cameroon Senegal Guinea Cambodia Yemen Madagascar
# Fiji =
# Philippines Vanuatu Bangladesh Armenia Thailand Cabo Verde Indonesia Bhutan Egypt Syria Kazakhstan
# Finland =
# United Kingdom Ireland Iceland Sweden Australia Slovenia Israel Malta Spain Italy New Zealand
# France =
# Germany Denmark Netherlands Canada Belgium New Zealand Austria Switzerland Spain Italy Portugal
# Gabon =
# Angola Botswana Central African Republic Namibia Chad Congo, Republic of the Nigeria Niger Cameroon Zambia Guinea-Bissau
# Gambia, The =
# Kenya Madagascar Ghana Papua New Guinea Comoros Yemen Benin Mauritania Ethiopia India Cambodia
# Georgia =
# Paraguay Solomon Islands Montenegro Bosnia and Herzegovina Maldives Jordan Nicaragua Cuba Serbia Brazil Honduras
# Germany =
# Denmark Belgium Canada Austria Netherlands France Switzerland New Zealand Ireland Sweden United Kingdom
# Ghana =
# Papua New Guinea Gambia, The Yemen Madagascar Nepal Kenya Comoros Bolivia Tajikistan Cambodia India
# Greece =
# Malta Spain Italy Slovenia Slovakia New Zealand Panama Portugal Argentina Finland Czech Republic
# Greenland =
# Bahamas, The Barbados Estonia Czech Republic Trinidad and Tobago Hungary Korea, South Taiwan Latvia Slovenia Poland
# Grenada =
# Romania Turkey Colombia Mauritius Mexico Tunisia Latvia Macedonia El Salvador Dominica Iran
# Guatemala =
# Vietnam Samoa Kosovo Kyrgyzstan El Salvador Korea, North Ukraine Iran Turkey Grenada Uzbekistan
# Guinea =
# Senegal Cote d'Ivoire Mauritania Cameroon Ethiopia Tanzania Western Sahara Cambodia Comoros Benin Zimbabwe
# Guinea-Bissau =
# Zambia Somalia Mozambique Nigeria Namibia Burkina Faso South Sudan Mali Swaziland Niger Chad
# Guyana =
# Belize Mongolia Tajikistan Iran Bolivia Nepal Kyrgyzstan Yemen Kosovo Ukraine Russia
# Haiti =
# Togo Djibouti Sao Tome and Principe Sudan Tanzania Western Sahara Malawi Burundi Senegal Cote d'Ivoire Cambodia
# Honduras =
# Iraq Nicaragua Jordan Brazil Solomon Islands Montenegro Maldives Georgia Ukraine Paraguay Kiribati
# Hungary =
# Croatia Barbados Uruguay Lithuania Bulgaria Argentina Chile Cyprus Poland Panama Saint Lucia
# Iceland =
# Sweden Ireland Australia United Kingdom Finland Japan Belgium Austria Israel Italy New Zealand
# India =
# Syria Papua New Guinea Bhutan Madagascar Bangladesh Bolivia Ghana Gambia, The Pakistan Fiji Mongolia
# Indonesia =
# Fiji Turkmenistan Bangladesh Philippines Vanuatu Sri Lanka Syria Thailand Armenia Pakistan Bhutan
# Iran =
# Suriname Russia Azerbaijan Belarus Belize Grenada Turkey Guyana Guatemala Kosovo Romania
# Iraq =
# Honduras Jordan Brazil Ukraine Maldives Kosovo Solomon Islands Samoa Montenegro Bulgaria Guatemala
# Ireland =
# United Kingdom Iceland Sweden Finland Australia Belgium Japan Austria New Zealand Spain Italy
# Israel =
# Korea, South Andorra San Marino Taiwan Finland Malta Czech Republic Iceland United Kingdom Ireland Australia
# Italy =
# Spain New Zealand Greece Malta United Kingdom Japan Finland Slovenia Ireland Sweden Portugal
# Jamaica =
# Egypt Peru China Azerbaijan Uzbekistan Tonga Suriname Saint Vincent and the Grenadines Venezuela Armenia Cabo Verde
# Japan =
# Sweden Iceland Australia Ireland United Kingdom Italy Spain Finland New Zealand Israel Belgium
# Jordan =
# Maldives Solomon Islands Iraq Brazil Georgia Honduras Montenegro Samoa Ecuador Paraguay Bulgaria
# Kazakhstan =
# Bhutan Syria Turkmenistan Fiji Peru Thailand Azerbaijan Suriname Vanuatu Philippines India
# Kenya =
# Gambia, The Madagascar Comoros Benin Ghana Ethiopia Mauritania Yemen Papua New Guinea Cambodia Nepal
# Kiribati =
# Sudan Moldova Honduras Togo Rwanda Nicaragua Haiti Djibouti Sao Tome and Principe Burundi Malawi
# Korea, North =
# Kyrgyzstan Kosovo Guatemala Ukraine Vietnam Samoa Tajikistan Guyana Iraq El Salvador Belize
# Korea, South =
# Israel Taiwan Andorra Czech Republic San Marino Malta Finland Slovenia Chile Poland Barbados
# Kosovo =
# Ukraine Guatemala Korea, North Samoa Vietnam Kyrgyzstan Iran El Salvador Iraq Turkey Guyana
# Kuwait =
# Brunei United Arab Emirates Singapore Saudi Arabia Oman Qatar Bahrain Seychelles Taiwan San Marino Liechtenstein
# Kyrgyzstan =
# Korea, North Guatemala Mongolia Kosovo Tajikistan Vietnam Belize Guyana Nepal Ukraine Uzbekistan
# Laos =
# Eritrea Burma Pakistan Madagascar Gambia, The Congo, Republic of the Kenya India Papua New Guinea Syria Benin
# Latvia =
# Turkey Mexico Grenada Lithuania Bulgaria Mauritius Estonia Romania Poland Antigua and Barbuda Russia
# Lebanon =
# Albania Tunisia Macedonia Dominica Colombia Morocco Mexico Dominican Republic Saint Lucia Romania Mauritius
# Lesotho =
# Rwanda Afghanistan Uganda Congo, Democratic Republic of the South Africa Burundi Swaziland Malawi Kiribati Sudan Somalia
# Liberia =
# Sierra Leone Marshall Islands Lesotho Micronesia, Federated States of Rwanda Moldova Kiribati Uganda Afghanistan United States Nicaragua
# Libya =
# Saint Vincent and the Grenadines Thailand Algeria China Armenia Saint Kitts and Nevis Peru Venezuela Tonga Dominican Republic Malaysia
# Liechtenstein =
# Luxembourg Singapore Norway Qatar Kuwait Australia San Marino Taiwan Iceland United Arab Emirates Brunei
# Lithuania =
# Poland Hungary Mexico Croatia Cyprus Latvia Saint Lucia Chile Bulgaria Barbados Uruguay
# Luxembourg =
# Liechtenstein Norway Singapore Australia Iceland Kuwait Taiwan San Marino Switzerland Austria Sweden
# Macedonia =
# Tunisia Colombia Lebanon Mexico El Salvador Ecuador Albania Grenada Dominica Romania Saint Lucia
# Madagascar =
# Gambia, The Papua New Guinea Kenya Ghana India Comoros Syria Yemen Laos Nepal Benin
# Malawi =
# Burundi Djibouti Sudan Congo, Democratic Republic of the Haiti Tanzania Togo Sao Tome and Principe Western Sahara Cote d'Ivoire Zimbabwe
# Malaysia =
# Saint Kitts and Nevis Thailand Libya Seychelles Saint Vincent and the Grenadines Peru Kazakhstan Algeria Armenia Venezuela Sri Lanka
# Maldives =
# Jordan Solomon Islands Brazil Montenegro Georgia Iraq Ecuador Paraguay Bulgaria Uruguay Croatia
# Mali =
# South Sudan Burkina Faso Zimbabwe Mozambique Cote d'Ivoire Somalia Zambia Niger Nigeria Guinea Guinea-Bissau
# Malta =
# Greece Slovenia Spain Italy Czech Republic Slovakia Israel Finland Panama Chile Argentina
# Marshall Islands =
# Micronesia, Federated States of Moldova Sierra Leone Liberia Costa Rica Serbia Nicaragua Bosnia and Herzegovina Cuba Portugal Kiribati
# Mauritania =
# Comoros Cambodia Senegal Yemen Ethiopia Benin Kenya Guinea Gambia, The Ghana Madagascar
# Mauritius =
# Romania Antigua and Barbuda Mexico Dominica Colombia Grenada Venezuela Tunisia Macedonia Latvia Lebanon
# Mexico =
# Mauritius Romania Colombia Antigua and Barbuda Grenada Dominica Macedonia Tunisia Turkey Latvia Lithuania
# Micronesia, Federated States of =
# Moldova Marshall Islands Serbia Costa Rica Nicaragua Bosnia and Herzegovina Cuba Paraguay Kiribati Georgia Montenegro
# Moldova =
# Nicaragua Kiribati Serbia Micronesia, Federated States of Honduras Bosnia and Herzegovina Georgia Montenegro Paraguay Brazil Costa Rica
# Monaco =
# Qatar Liechtenstein Luxembourg Singapore Kuwait Norway Brunei United Arab Emirates Australia Switzerland San Marino
# Mongolia =
# Bolivia Belize Guyana Nepal Tajikistan Cabo Verde Kyrgyzstan Azerbaijan Bhutan Ghana Papua New Guinea
# Montenegro =
# Brazil Georgia Maldives Paraguay Serbia Bosnia and Herzegovina Solomon Islands Jordan Nicaragua Cuba Iraq
# Morocco =
# Tunisia Albania Tonga Lebanon Colombia Dominican Republic Macedonia China El Salvador Dominica Romania
# Mozambique =
# Somalia Zambia Burkina Faso South Sudan Mali Guinea-Bissau Zimbabwe Nigeria Niger Swaziland Namibia
# Burma =
# Pakistan Eritrea Laos Turkmenistan Syria India Madagascar Indonesia Bangladesh Papua New Guinea Bhutan
# Namibia =
# Nigeria Zambia Botswana Niger Chad Guinea-Bissau Mozambique Burkina Faso Central African Republic Somalia Cameroon
# Nauru =
# Tuvalu Palau Western Sahara Kiribati Kosovo Honduras Sudan Moldova Togo Nicaragua Sao Tome and Principe
# Nepal =
# Tajikistan Yemen Ghana Mongolia Bolivia Papua New Guinea Guyana Cambodia Belize Comoros Kyrgyzstan
# Netherlands =
# Canada Germany France Denmark Switzerland Belgium Austria New Zealand Sweden Ireland United Kingdom
# New Zealand =
# Spain Italy United Kingdom Portugal Ireland Greece Belgium Finland Slovenia Sweden France
# Nicaragua =
# Honduras Serbia Georgia Bosnia and Herzegovina Montenegro Paraguay Solomon Islands Brazil Moldova Jordan Maldives
# Niger =
# Nigeria Cameroon Burkina Faso Zambia Namibia Mozambique Mali South Sudan Zimbabwe Guinea Cote d'Ivoire
# Nigeria =
# Niger Namibia Zambia Mozambique Guinea-Bissau Burkina Faso Chad Cameroon Central African Republic Mali Somalia
# Norway =
# Australia Iceland Sweden Austria Switzerland Ireland United Kingdom Finland Belgium Canada Japan
# Oman =
# Saudi Arabia Seychelles Bahrain Malaysia Saint Kitts and Nevis United Arab Emirates Kazakhstan Turkmenistan Libya Thailand Brunei
# Pakistan =
# Burma Laos Eritrea Syria Turkmenistan India Bangladesh Madagascar Indonesia Papua New Guinea Bhutan
# Palau =
# Serbia Nicaragua Bosnia and Herzegovina Montenegro Moldova Brazil Georgia Paraguay Costa Rica Honduras Cuba
# Panama =
# Argentina Uruguay Croatia Chile Cyprus Hungary Saint Lucia Slovakia Lithuania Ecuador Bulgaria
# Papua New Guinea =
# India Ghana Madagascar Gambia, The Syria Bolivia Bhutan Nepal Kenya Mongolia Yemen
# Paraguay =
# Georgia Bosnia and Herzegovina Cuba Montenegro Serbia Solomon Islands Maldives Nicaragua Costa Rica Brazil Jordan
# Peru =
# Jamaica Saint Vincent and the Grenadines Azerbaijan Venezuela Egypt Suriname China Thailand Belarus Armenia Libya
# Philippines =
# Vanuatu Fiji Armenia Cabo Verde Bangladesh Egypt Thailand Bhutan Peru Jamaica Uzbekistan
# Poland =
# Lithuania Antigua and Barbuda Mexico Cyprus Chile Hungary Latvia Estonia Czech Republic Saint Lucia Croatia
# Portugal =
# New Zealand Costa Rica Spain Greece Slovakia Italy Cuba Slovenia Malta Serbia Bosnia and Herzegovina
# Qatar =
# Kuwait Liechtenstein Singapore Brunei Luxembourg United Arab Emirates Saudi Arabia Oman Norway Taiwan San Marino
# Romania =
# Mauritius Colombia Grenada Mexico Dominica Tunisia Venezuela Antigua and Barbuda China Macedonia Turkey
# Russia =
# Iran Trinidad and Tobago Belarus Latvia Turkey Suriname Grenada Belize Guyana Timor-Leste Azerbaijan
# Rwanda =
# Uganda Burundi Kiribati Malawi Congo, Democratic Republic of the Sudan Lesotho Djibouti Afghanistan Haiti Togo
# Saint Kitts and Nevis =
# Malaysia Saint Vincent and the Grenadines Libya Venezuela Peru Thailand Seychelles Belarus China Antigua and Barbuda Mauritius
# Saint Lucia =
# Ecuador Cyprus Croatia Macedonia Chile Lithuania Uruguay Lebanon Mexico Argentina Albania
# Saint Vincent and the Grenadines =
# Venezuela China Peru Libya Jamaica Tonga Saint Kitts and Nevis Thailand Romania Egypt Belarus
# Samoa =
# Vietnam El Salvador Guatemala Kosovo Macedonia Turkey Ecuador Korea, North Tunisia Grenada Colombia
# San Marino =
# Andorra Israel Taiwan Korea, South Australia Iceland Finland Japan Sweden United Kingdom Ireland
# Sao Tome and Principe =
# Togo Haiti Djibouti Sudan Tanzania Western Sahara Malawi Ukraine Burundi Korea, North Cambodia
# Saudi Arabia =
# Seychelles Oman Bahrain United Arab Emirates Saint Kitts and Nevis Malaysia Estonia Trinidad and Tobago Brunei Belarus Venezuela
# Senegal =
# Guinea Mauritania Cambodia Comoros Western Sahara Cote d'Ivoire Tanzania Ethiopia Yemen Benin Cameroon
# Serbia =
# Bosnia and Herzegovina Paraguay Montenegro Cuba Costa Rica Nicaragua Georgia Brazil Solomon Islands Maldives Portugal
# Seychelles =
# Saudi Arabia Malaysia Saint Kitts and Nevis Bahrain Oman Trinidad and Tobago Saint Vincent and the Grenadines Libya Venezuela Kazakhstan Belarus
# Sierra Leone =
# Liberia Marshall Islands Lesotho Micronesia, Federated States of Rwanda Moldova Kiribati Uganda Afghanistan Nicaragua Burundi
# Singapore =
# Kuwait United Arab Emirates Brunei San Marino Taiwan Andorra Liechtenstein Luxembourg Norway Korea, South Israel
# Slovakia =
# Slovenia Greece Malta Argentina Panama Barbados Uruguay Hungary Croatia Portugal Czech Republic
# Slovenia =
# Slovakia Malta Greece Finland Spain Italy United Kingdom New Zealand Czech Republic Portugal Barbados
# Solomon Islands =
# Jordan Maldives Georgia Paraguay Montenegro Brazil Honduras Iraq Nicaragua Bosnia and Herzegovina Ecuador
# Somalia =
# Mozambique Guinea-Bissau Zambia South Sudan Mali Burkina Faso Swaziland Zimbabwe Nigeria Namibia Niger
# South Africa =
# Swaziland Afghanistan Somalia Uganda Mozambique Guinea-Bissau South Sudan Congo, Democratic Republic of the Zambia Mali Zimbabwe
# South Sudan =
# Mali Zimbabwe Burkina Faso Mozambique Somalia Cote d'Ivoire Zambia Congo, Democratic Republic of the Niger Guinea-Bissau Swaziland
# Spain =
# Italy New Zealand Greece Malta United Kingdom Slovenia Finland Portugal Ireland Japan Sweden
# Sri Lanka =
# Algeria Thailand Armenia Libya Vanuatu Fiji Philippines Indonesia Malaysia Egypt Saint Vincent and the Grenadines
# Sudan =
# Togo Haiti Djibouti Sao Tome and Principe Malawi Tanzania Burundi Western Sahara Kiribati Congo, Democratic Republic of the Ukraine
# Suriname =
# Azerbaijan Belarus Peru Iran Jamaica Venezuela Egypt Saint Vincent and the Grenadines Grenada Romania China
# Swaziland =
# Somalia South Africa Mozambique Afghanistan South Sudan Guinea-Bissau Mali Zambia Uganda Zimbabwe Burkina Faso
# Sweden =
# Iceland Ireland United Kingdom Australia Japan Finland Belgium Austria New Zealand Italy Spain
# Switzerland =
# Canada Austria Germany Belgium Netherlands Denmark Sweden France Ireland Australia Iceland
# Syria =
# India Bhutan Papua New Guinea Bangladesh Bolivia Kazakhstan Turkmenistan Fiji Madagascar Pakistan Philippines
# Taiwan =
# Korea, South Andorra Israel San Marino Czech Republic Finland Iceland Australia Malta United Kingdom Ireland
# Tajikistan =
# Nepal Yemen Mongolia Guyana Belize Kyrgyzstan Cambodia Ghana Bolivia Comoros Papua New Guinea
# Tanzania =
# Western Sahara Djibouti Haiti Sao Tome and Principe Togo Malawi Cote d'Ivoire Senegal Sudan Guinea Burundi
# Thailand =
# Armenia Libya Peru Algeria Vanuatu Saint Vincent and the Grenadines Egypt Philippines Fiji Sri Lanka Jamaica
# Timor-Leste =
# Russia Trinidad and Tobago Belarus Belize Kazakhstan Guyana Suriname Equatorial Guinea Iran Azerbaijan Bolivia
# Togo =
# Haiti Sao Tome and Principe Sudan Djibouti Tanzania Western Sahara Malawi Burundi Ukraine Korea, North Senegal
# Tonga =
# China Dominican Republic Jamaica Morocco Saint Vincent and the Grenadines Egypt Tunisia Colombia Venezuela Uzbekistan Romania
# Trinidad and Tobago =
# Estonia Belarus Russia Latvia Mauritius Venezuela Suriname Grenada Antigua and Barbuda Romania Iran
# Tunisia =
# Colombia Macedonia Lebanon Romania Dominica Morocco Albania Grenada Mexico El Salvador Mauritius
# Turkey =
# Latvia Grenada Mexico Romania El Salvador Bulgaria Macedonia Colombia Mauritius Iran Tunisia
# Turkmenistan =
# Indonesia Syria Kazakhstan Pakistan Bhutan India Bangladesh Fiji Burma Philippines Vanuatu
# Tuvalu =
# Nauru Palau Marshall Islands Sierra Leone Liberia Micronesia, Federated States of Moldova Lesotho Rwanda Kiribati Nicaragua
# Uganda =
# Congo, Democratic Republic of the Afghanistan Burundi Swaziland Rwanda Malawi South Africa South Sudan Zimbabwe Somalia Mali
# Ukraine =
# Kosovo Korea, North Guatemala Iraq Kyrgyzstan Samoa Vietnam Guyana Iran Belize El Salvador
# United Arab Emirates =
# Brunei Kuwait Saudi Arabia Oman Bahrain Seychelles Singapore Taiwan Saint Kitts and Nevis Malaysia Estonia
# United Kingdom =
# Ireland Finland Iceland Sweden Australia New Zealand Spain Italy Japan Belgium Slovenia
# United States =
# Netherlands France Canada Marshall Islands Denmark Germany Switzerland Austria Belgium Micronesia, Federated States of New Zealand
# Uruguay =
# Croatia Argentina Panama Hungary Chile Cyprus Saint Lucia Bulgaria Lithuania Ecuador Barbados
# Uzbekistan =
# Egypt Jamaica Cabo Verde Tonga China Azerbaijan Armenia Peru Morocco Suriname Vanuatu
# Vanuatu =
# Philippines Fiji Armenia Cabo Verde Egypt Thailand Bangladesh Peru Jamaica Bhutan Algeria
# Venezuela =
# Saint Vincent and the Grenadines China Peru Romania Mauritius Belarus Jamaica Suriname Azerbaijan Tonga Dominica
# Vietnam =
# Samoa Guatemala El Salvador Kosovo Korea, North Kyrgyzstan Macedonia Tunisia Uzbekistan Ukraine Morocco
# Western Sahara =
# Tanzania Djibouti Haiti Sao Tome and Principe Senegal Togo Guinea Cambodia Cote d'Ivoire Sudan Mauritania
# Yemen =
# Cambodia Comoros Ghana Tajikistan Nepal Mauritania Kenya Gambia, The Papua New Guinea Senegal Guyana
# Zambia =
# Mozambique Guinea-Bissau Nigeria Somalia Burkina Faso Namibia Mali Niger South Sudan Zimbabwe Chad
# Zimbabwe =
# Mali South Sudan Burkina Faso Cote d'Ivoire Mozambique Somalia Congo, Democratic Republic of the Zambia Guinea Niger Tanzania
#                     Country                            Closest Farthest
# 0               Afghanistan                             Uganda   Monaco
# 1                   Albania                            Lebanon    Nauru
# 2                   Algeria                          Sri Lanka    Nauru
# 3                   Andorra                         San Marino    Nauru
# 4                    Angola             Congo, Republic of the    Nauru
# 5       Antigua and Barbuda                          Mauritius    Nauru
# 6                 Argentina                            Uruguay    Nauru
# 7                   Armenia                           Thailand    Nauru
# 8                 Australia                            Iceland    Nauru
# 9                   Austria                            Belgium    Nauru
# 10               Azerbaijan                           Suriname    Nauru
# 11             Bahamas, The                          Greenland    Nauru
# 12                  Bahrain                         Seychelles    Nauru
# 13               Bangladesh                               Fiji    Nauru
# 14                 Barbados                            Hungary    Nauru
# 15                  Belarus                           Suriname    Nauru
# 16                  Belgium                            Austria    Nauru
# 17                   Belize                             Guyana    Nauru
# 18                    Benin                           Ethiopia    Nauru
# 19                   Bhutan                              Syria    Nauru
# 20                  Bolivia                           Mongolia    Nauru
# 21   Bosnia and Herzegovina                           Paraguay    Nauru
# 22                 Botswana                            Namibia    Nauru
# 23                   Brazil                         Montenegro    Nauru
# 24                   Brunei               United Arab Emirates    Nauru
# 25                 Bulgaria                            Hungary    Nauru
# 26             Burkina Faso                               Mali   Monaco
# 27                  Burundi                             Malawi   Monaco
# 28               Cabo Verde                              Egypt    Nauru
# 29                 Cambodia                              Yemen    Nauru
# ..                      ...                                ...      ...
# 167               Swaziland                            Somalia   Monaco
# 168                  Sweden                            Iceland    Nauru
# 169             Switzerland                             Canada    Nauru
# 170                   Syria                              India    Nauru
# 171                  Taiwan                       Korea, South    Nauru
# 172              Tajikistan                              Nepal    Nauru
# 173                Tanzania                     Western Sahara    Nauru
# 174                Thailand                            Armenia    Nauru
# 175             Timor-Leste                             Russia    Nauru
# 176                    Togo                              Haiti    Nauru
# 177                   Tonga                              China    Nauru
# 178     Trinidad and Tobago                            Estonia    Nauru
# 179                 Tunisia                           Colombia    Nauru
# 180                  Turkey                             Latvia    Nauru
# 181            Turkmenistan                          Indonesia    Nauru
# 182                  Tuvalu                              Nauru   Monaco
# 183                  Uganda  Congo, Democratic Republic of the   Monaco
# 184                 Ukraine                             Kosovo    Nauru
# 185    United Arab Emirates                             Brunei    Nauru
# 186          United Kingdom                            Ireland    Nauru
# 187           United States                        Netherlands    Nauru
# 188                 Uruguay                            Croatia    Nauru
# 189              Uzbekistan                              Egypt    Nauru
# 190                 Vanuatu                        Philippines    Nauru
# 191               Venezuela   Saint Vincent and the Grenadines    Nauru
# 192                 Vietnam                              Samoa    Nauru
# 193          Western Sahara                           Tanzania   Monaco
# 194                   Yemen                           Cambodia    Nauru
# 195                  Zambia                         Mozambique   Monaco
# 196                Zimbabwe                               Mali   Monaco
#
# [197 rows x 3 columns]
